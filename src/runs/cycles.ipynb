# %%
import os
import sys
sys.path.append("..")

from analysis_util.visualize import *

# %%
current_dir = os.getcwd()
file_path = os.path.join(current_dir, '..', '..', 'data', 'simulation_data.h5')
file = h5py.File(file_path, 'r')

# %% [markdown]
# ### Baseline

# %%
group = file["Gamma098"]

pi1_L = group['pi1_L'][:]
pi2_L = group['pi2_L'][:]
q1_L = group['q1_L'][:]
q2_L = group['q2_L'][:]
theta1_L = group['theta1_L'][:]
theta2_L = group['theta2_L'][:]

# %%
visualize_last_L(pi1_L[0], pi2_L[0], theta1_L[0], theta2_L[0], q1_L[0], q2_L[0])

# %%
visualize_last_L(pi1_L[9], pi2_L[9], theta1_L[9], theta2_L[9], q1_L[9], q2_L[9])

# %%
visualize_last_L(pi1_L[666], pi2_L[666], theta1_L[666], theta2_L[666], q1_L[666], q2_L[666])

# %% [markdown]
# ### Diminished Consumer Welfare Evaluation

# %%
group = file["V4gamma098"]

pi1_L = group['pi1_L'][:]
pi2_L = group['pi2_L'][:]
q1_L = group['q1_L'][:]
q2_L = group['q2_L'][:]
theta1_L = group['theta1_L'][:]
theta2_L = group['theta2_L'][:]

# %% [markdown]
# Agents found out that take turns in production, this was the only time found in the whole study that they set q=0 to do this

# %%
visualize_last_L(pi1_L[4], pi2_L[4], theta1_L[4], theta2_L[4], q1_L[4], q2_L[4])

# %%
visualize_last_L(pi1_L[474], pi2_L[474], theta1_L[474], theta2_L[474], q1_L[474], q2_L[474])

# %%
visualize_last_L(pi1_L[678], pi2_L[678], theta1_L[678], theta2_L[678], q1_L[678], q2_L[678])

# %%
visualize_last_L(pi1_L[222], pi2_L[222], theta1_L[222], theta2_L[222], q1_L[222], q2_L[222])

# %%
visualize_last_L(pi1_L[8], pi2_L[8], theta1_L[8], theta2_L[8], q1_L[8], q2_L[8])
