# %%
import sys
sys.path.append("..")

from algorithms import *
from analysis_util.cylcle_classifier import Cycle_Classifier
from analysis_util.visualize import *
from classes.environment import Environment

import h5py
import os

# Used for seed in np.random
Reproduce = 2023

# %%
env = Environment()
Qs = [1 + 0.5*i for i in range(7)]
Thetas = [0, 1/6, 2/6, 3/6, 4/6, 5/6, 1]

# %% [markdown]
# Example useage

# %%
np.random.seed(Reproduce)
pi1_L, pi2_L, theta1_L, theta2_L, q1_L, q2_L, \
pi1_t, pi2_t, theta1_t, theta2_t, q1_t, q2_t, Q1, Q2 = \
simulate_episode_Qlearning(env, Qs, Thetas)

# %%
visualize_last_L(pi1_L, pi2_L, theta1_L, theta2_L, q1_L, q2_L)

# %% [markdown]
# Reproduction results

# %%
visualize_over_gamma(env, ["Gamma075", "Gamma08", "Gamma085", "TheBaseline", "Gamma095", "Gamma098"])

# %%
visualize_convergence_over_T(env, "TheBaseline", 0.9)

# %% [markdown]
# Make sure you make a folder data in the root directory with a simulation_data.h5 file (data/simulation_data.h5)

# %%
np.random.seed(Reproduce)
simulate_episodes("FileName", env, Qs, Thetas)
